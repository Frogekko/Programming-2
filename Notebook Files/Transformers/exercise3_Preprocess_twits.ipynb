# %% [markdown]
# # Oppgave: Preprocess the text column in the given file.

# %%
import numpy as np
import pandas as pd
import re
import nltk
#import spacy
import string
pd.options.mode.chained_assignment = None

# %% [markdown]
# # Lower Casing

# %% [markdown]
# # Removal of Punctuations

# %% [markdown]
# # Removal of stopwords

# %% [markdown]
# # Removal of Frequent words

# %% [markdown]
# # Removal of Rare words

# %% [markdown]
# # Stemming

# %% [markdown]
# # Lemmatization

# %% [markdown]
# # Removal of Emojis

# %% [markdown]
# # Removal of HTML Tags

# %% [markdown]
# # Chat Words Conversion
