# %% [markdown]
# # implement a preprocessing function that converts all words to lowercase.

# %% [markdown]
# # Implement: Tokenize a given paragraph into individual words, where each word should be treated as a separate entity (remove punctuation and special characters).

# %% [markdown]
# # wrtie a code that Given a paragraph containing URLs and email addresses (e.g., “Contact us at support@example.com or visit https://www.example.com”), remove or replace these patterns with placeholders (e.g., <URL> and <EMAIL>).

# %% [markdown]
# # Given a large text, calculate the frequency of each word and plot the top 5 most frequent words using a bar chart.

# %% [markdown]
# # Given a set of documents, implement a function that selectively preserves case for some key words (like names, brand names, or technical terms), but lowercases all other words.
