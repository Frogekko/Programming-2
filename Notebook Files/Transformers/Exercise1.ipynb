# %%
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
import requests

# %% [markdown]
# # download the data
#
# # use the url below to download the data and save it in a text file.

# %%
# URL of the text file you want to download
url = "https://www.gutenberg.org/files/1661/1661-0.txt"  # Example URL for "The Adventures of Sherlock Holmes"

# %% [markdown]
# # Preprocess the data

# %%
import nltk
import re
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize, sent_tokenize
from collections import Counter
from nltk.corpus import stopwords

# %% [markdown]
# # give the Total Sentences and plot the top 10 most frequent words.

# %% [markdown]
# # Download the second example from url below and save it in a text file

# %%
url = "https://www.w3.org/TR/PNG/iso_8859-1.txt"  # This URL contains a sample text file (ISO 8859-1 encoded PNG example)

# %% [markdown]
# # Preprocess the example 2

# %% [markdown]
# # give the Total Sentences and plot the top 10 most frequent words.

# %% [markdown]
# # Download the example 3 from the url below and save it in a text file

# %%
url = "https://raw.githubusercontent.com/dwyl/english-words/master/words.txt"  # A list of English words from GitHub

# %% [markdown]
# # preprocess the example 3

# %% [markdown]
# # give the Total Sentences and plot the top 10 most frequent words.
